# %% [markdown]
# ### Task 3 Unsupervised learning

# %% [markdown]
# #### Problem statement

# %% [markdown]
# From the given iris dataset predict the optimum number of clusters and represent it visually

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import datasets

# %% [markdown]
# ### Loading the dataset

# %%
dt = pd.read_csv('C:\\Users\\sreek\\Downloads\\iris.csv')
dt.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dt.shape
# Out:
# (150, 6)

# %%
dt.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %% [markdown]
# removing the word prefix from each attribute in the dataset

# %%
dt.loc[dt['Species']=="Iris-setosa",['Species']]='Setosa'
dt.loc[dt['Species']=="Iris-virginica",['Species']]='Virginica'
dt.loc[dt['Species']=="Iris-versicolor",['Species']]='Versicolor'

# %% [markdown]
# ### Data visualization

# %% [markdown]
# ### -Scatterplot

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=dt,hue='Species')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# sepal length vs sepal width

# %%
plt.scatter(dt.SepalLengthCm,dt.SepalWidthCm)

# %%
plt.scatter(dt.PetalLengthCm,dt.PetalWidthCm)

# %% [markdown]
# ### -Pair plot

# %%
sns.pairplot(dt,hue='Species')

# %% [markdown]
# ### Finding the optimum number of clusters for k-means classification

# %%
x = dt.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# ### Applying kmeans to the dataset

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# ### Visualising the clusters

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()
